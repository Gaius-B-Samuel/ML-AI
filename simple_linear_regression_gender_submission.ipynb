# %%
import pandas as pd
import matplotlib.pyplot as plt #visualization
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/ML & AI/gender_submission linear regression.csv')

# %%
df
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
df.head(20)
# Out:
#     PassengerId  Survived
# 0           892         0
# 1           893         1
# 2           894         0
# 3           895         0
# 4           896         1
# 5           897         0
# 6           898         1
# 7           899         0
# 8           900         1
# 9           901         0
# 10          902         0
# 11          903         0
# 12          904         1
# 13          905         0
# 14          906         1
# 15          907         1
# 16          908         0
# 17          909         0
# 18          910         1
# 19          911         1

# %%
df.tail(20)
# Out:
#      PassengerId  Survived
# 398         1290         0
# 399         1291         0
# 400         1292         1
# 401         1293         0
# 402         1294         1
# 403         1295         0
# 404         1296         0
# 405         1297         0
# 406         1298         0
# 407         1299         0
# 408         1300         1
# 409         1301         1
# 410         1302         1
# 411         1303         1
# 412         1304         1
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0

# %%
plt.scatter(x=df['PassengerId'], y=df['Survived'])
plt.show()

# %%
X = df[['PassengerId']]
y = df[['Survived']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
lr=LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([[0.36375976],
#        [0.3543496 ],
#        [0.37577582],
#        [0.39256934],
#        [0.34913781],
#        [0.38822619],
#        [0.35232279],
#        [0.34320217],
#        [0.34551852],
#        [0.35985092],
#        [0.34262308],
#        [0.3620225 ],
#        [0.3922798 ],
#        [0.36926109],
#        [0.34624238],
#        [0.36274636],
#        [0.39401706],
#        [0.38504121],
#        [0.3943066 ],
#        [0.36289113],
#        [0.39314843],
#        [0.36781337],
#        [0.3563764 ],
#        [0.37447287],
#        [0.36245681],
#        [0.38533075],
#        [0.36332545],
#        [0.34754532],
#        [0.37259084],
#        [0.37345947],
#        [0.37939511],
#        [0.35261233],
#        [0.36607611],
#        [0.35565254],
#        [0.34899304],
#        [0.39010822],
#        [0.39416183],
#        [0.38286963],
#        [0.36549702],
#        [0.36810291],
#        [0.34378126],
#        [0.34711101],
#        [0.36216727],
#        [0.39474092],
#        [0.38952913],
#        [0.36390453],
#        [0.38677847],
#        [0.39300366],
#        [0.355363  ],
#        [0.35753457],
#        [0.38793664],
#        [0.37765785],
#        [0.36853723],
#        [0.35970615],
#        [0.38895005],
#        [0.36433885],
#        [0.38981868],
#        [0.35579731],
#        [0.36955063],
#        [0.3517437 ],
#        [0.35695549],
#        [0.34928258],
#        [0.36231204],
#        [0.36897154],
#        [0.37809216],
#        [0.37649968],
#        [0.36911632],
#        [0.36824769],
#        [0.39025299],
#        [0.38185623],
#        [0.35391528],
#        [0.34276785],
#        [0.34667669],
#        [0.35854798],
#        [0.36984017],
#        [0.34841395],
#        [0.39039776],
#        [0.342044  ],
#        [0.34045151],
#        [0.37881602],
#        [0.34247831],
#        [0.35883752],
#        [0.37056403],
#        [0.37910557]])

# %%
y_test
# Out:
#      Survived
# 222         1
# 287         0
# 139         0
# 23          0
# 323         0
# ..        ...
# 118         0
# 369         0
# 256         0
# 175         1
# 116         0
#
# [84 rows x 1 columns]

# %%
print(mean_squared_error(y_pred, y_test))
# Out:
# 0.23049486445148504
