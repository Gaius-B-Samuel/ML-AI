# %%
import pandas as pd
import matplotlib.pyplot as plt #visualization
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/ML & AI/test data linear regression.csv')

# %%
df
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
df.head(20)
# Out:
#      x          y
# 0   77  79.775152
# 1   21  23.177279
# 2   22  25.609262
# 3   20  17.857388
# 4   36  41.849864
# 5   15   9.805235
# 6   62  58.874659
# 7   95  97.617937
# 8   20  18.395127
# 9    5   8.746748
# 10   4   2.811416
# 11  19  17.095372
# 12  96  95.149072
# 13  62  61.388007
# 14  36  40.247017
# 15  15  14.822486
# 16  65  66.958069
# 17  14  16.635080
# 18  87  90.655137
# 19  69  77.229826

# %%
df.tail(20)
# Out:
#       x          y
# 280  19  21.426378
# 281  25  30.413033
# 282  64  67.681421
# 283  21  17.085478
# 284  59  60.917927
# 285  19  14.995143
# 286  16  16.749239
# 287  42  41.469239
# 288  43  42.845261
# 289  61  59.129130
# 290  92  91.308637
# 291  11   8.673336
# 292  41  39.314853
# 293   1   5.313686
# 294   8   5.405221
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467

# %%
plt.scatter(x=df['x'], y=df['y'])
plt.show()

# %%
X = df[['x']]
y = df[['y']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
lr=LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([[64.38965862],
#        [35.96745014],
#        [75.55552623],
#        [60.32934312],
#        [78.60076285],
#        [96.87218259],
#        [59.31426425],
#        [58.29918537],
#        [42.05792339],
#        [42.05792339],
#        [59.31426425],
#        [94.84202484],
#        [72.51028961],
#        [26.83174028],
#        [32.92221352],
#        [ 4.50000505],
#        [90.78170934],
#        [-0.57538932],
#        [22.77142478],
#        [52.20871213],
#        [43.07300226],
#        [51.19363326],
#        [57.2841065 ],
#        [56.26902763],
#        [20.74126703],
#        [37.99760789],
#        [48.14839663],
#        [90.78170934],
#        [71.49521074],
#        [ 3.48492618],
#        [64.38965862],
#        [82.66107835],
#        [15.66587266],
#        [65.40473749],
#        [87.73647272],
#        [39.01268677],
#        [50.17855438],
#        [ 3.48492618],
#        [81.64599948],
#        [46.11823889],
#        [78.60076285],
#        [74.54044736],
#        [12.62063604],
#        [36.98252902],
#        [72.51028961],
#        [74.54044736],
#        [19.72618816],
#        [-0.57538932],
#        [33.9372924 ],
#        [68.44997411],
#        [76.57060511],
#        [20.74126703],
#        [ 5.51508392],
#        [89.76663047],
#        [93.82694597],
#        [27.84681915],
#        [99.91741921],
#        [ 6.5301628 ],
#        [53.223791  ],
#        [12.62063604]])

# %%
y_test
# Out:
#              y
# 282  67.681421
# 4    41.849864
# 131  74.253628
# 253  60.111350
# 126  74.499360
# 12   95.149072
# 88   56.824570
# 25   57.016314
# 160  38.983174
# 287  41.469239
# 284  60.917927
# 152  97.001484
# 273  77.996948
# 29   26.591124
# 39   36.346442
# 9     8.746748
# 203  92.887723
# 109  -2.344739
# 277  25.690415
# 78   52.019323
# 89   48.672526
# 21   46.913877
# 199  53.116284
# 252  61.093678
# 96   16.890852
# 91   38.430764
# 222  47.410067
# 107  98.132580
# 41   68.167248
# 44    5.607665
# 138  64.375211
# 64   85.455042
# 260  16.828397
# 16   66.958069
# 227  88.803069
# 243  36.792248
# 67   50.963436
# 219   7.646530
# 76   73.930876
# 70   46.561418
# 255  81.403818
# 202  75.074847
# 71   10.347545
# 45   36.113348
# 269  68.197219
# 235  72.913885
# 8    18.395127
# 55   -1.040114
# 267  34.588765
# 80   70.369875
# 43   78.042375
# 283  17.085478
# 257   2.576625
# 22   89.826344
# 182  99.435779
# 34   33.071128
# 30   97.551553
# 220   9.281700
# 73   50.170086
# 69   17.076111

# %%
print(mean_squared_error(y_pred, y_test))
# Out:
# 10.089336372280014
