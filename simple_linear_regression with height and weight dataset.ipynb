# %%
import pandas as pd
import matplotlib.pyplot as plt #visualization
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/ML & AI/dataheights and weights.csv')

# %%
df
# Out:
#     Height  Weight
# 0     1.47   52.21
# 1     1.50   53.12
# 2     1.52   54.48
# 3     1.55   55.84
# 4     1.57   57.20
# 5     1.60   58.57
# 6     1.63   59.93
# 7     1.65   61.29
# 8     1.68   63.11
# 9     1.70   64.47
# 10    1.73   66.28
# 11    1.75   68.10
# 12    1.78   69.92
# 13    1.80   72.19
# 14    1.83   74.46

# %%
df.head()
# Out:
#    Height  Weight
# 0    1.47   52.21
# 1    1.50   53.12
# 2    1.52   54.48
# 3    1.55   55.84
# 4    1.57   57.20

# %%
df.tail()
# Out:
#     Height  Weight
# 10    1.73   66.28
# 11    1.75   68.10
# 12    1.78   69.92
# 13    1.80   72.19
# 14    1.83   74.46

# %%
plt.scatter(x=df['Height'], y=df['Weight'])
plt.show()

# %%
X = df[['Height']]
y = df[['Weight']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
lr=LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([[55.87805434],
#        [65.14172498],
#        [54.02532021]])

# %%
y_test
# Out:
#    Weight
# 3   55.84
# 9   64.47
# 2   54.48

# %%
print(mean_squared_error(y_pred, y_test))
# Out:
# 0.21979876372926696
