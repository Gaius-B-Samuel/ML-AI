# %%
import pandas as pd
import matplotlib.pyplot as plt #visualization
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/ML & AI/Salary_Data simple linear regression.csv')

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.head(10)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# 5              2.9  56642.0
# 6              3.0  60150.0
# 7              3.2  54445.0
# 8              3.2  64445.0
# 9              3.7  57189.0

# %%
df.tail(10)
# Out:
#        0          1
# 21   6.8   91738.00
# 22   7.1   98273.00
# 23   7.9  101302.00
# 24   8.2  113812.00
# 25   8.7  109431.00
# 26   9.0  105582.00
# 27   9.5  116969.00
# 28   9.6  112635.00
# 29  10.3  122391.00
# 30  10.5  121872.00

# %%
plt.scatter(x=df['YearsExperience'], y=df['Salary'])
plt.show()

# %%
X = df[['YearsExperience']]
y = df[['Salary']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
lr=LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([[ 90006.44955119],
#        [ 36138.06387681],
#        [ 75830.55858425],
#        [ 63544.7864129 ],
#        [123083.52847406],
#        [ 60709.60821951]])

# %%
y_test
# Out:
#       Salary
# 20   91738.0
# 0    39343.0
# 17   83088.0
# 12   56957.0
# 28  122391.0
# 9    57189.0

# %%
print(mean_squared_error(y_pred, y_test))
# Out:
# 20368924.359697726
